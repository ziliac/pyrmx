# %%
import include
import ensembles
from importlib import reload
reload(include)
reload(ensembles)
from include import *

# %%
n = 1000
A = ensembles.GUE(n)

# %%
fig = A.eig_gaps_hist(kde=False, norm_hist=True)
# Out:
# C:\Users\chezi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
